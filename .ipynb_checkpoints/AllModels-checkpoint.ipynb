# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
import shap
from tqdm import tqdm
#To remove warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('processed.csv')

# %%
df['RUL'].nunique()
# Out:
# 9383

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16916 entries, 0 to 16915
# Data columns (total 56 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   workpiece_weight, tonn                                       16916 non-null  float64
#  1   steel_type                                                   16916 non-null  int64
#  2   doc_requirement                                              16916 non-null  int64
#  3   cast_in_row                                                  16916 non-null  int64
#  4   steel_weight_theoretical, tonn                               16916 non-null  float64
#  5   slag_weight_close_grab1, tonn                                16916 non-null  float64
#  6   metal_residue_grab1, tonn                                    16916 non-null  float64
#  7   steel_weight, tonn                                           16916 non-null  float64
#  8   grab1_num                                                    16916 non-null  float64
#  9   steel_temperature_grab1, Celsius deg.                        16916 non-null  float64
#  10  grab2_num                                                    16916 non-null  float64
#  11  resistance, tonn                                             16916 non-null  float64
#  12  swing_frequency, amount/minute                               16916 non-null  int64
#  13  crystallizer_movement, mm                                    16916 non-null  int64
#  14  alloy_speed, meter/minute                                    16916 non-null  int64
#  15  water_consumption, liter/minute                              16916 non-null  int64
#  16  water_temperature_delta, Celsius deg.                        16916 non-null  int64
#  17  water_consumption_secondary_cooling_zone_num1, liter/minute  16916 non-null  int64
#  18  water_consumption_secondary_cooling_zone_num2, liter/minute  16916 non-null  int64
#  19  water_consumption_secondary_cooling_zone_num3, liter/minute  16916 non-null  float64
#  20  quantity, tonn                                               16916 non-null  float64
#  21  time_temperature_measurement1                                16916 non-null  int64
#  22  temperature_measurement1, Celsius deg.                       16916 non-null  float64
#  23  time_temperature_measurement2                                16916 non-null  int64
#  24  temperature_measurement2, Celsius deg.                       16916 non-null  float64
#  25  sample_time_continuous_caster                                16916 non-null  int64
#  26  Ce, %                                                        16916 non-null  float64
#  27  C, %                                                         16916 non-null  float64
#  28  Si, %                                                        16916 non-null  float64
#  29  Mn,%                                                         16916 non-null  float64
#  30  S, %                                                         16916 non-null  float64
#  31  P, %                                                         16916 non-null  float64
#  32  Cr, %                                                        16916 non-null  float64
#  33  Ni, %                                                        16916 non-null  float64
#  34  Cu, %                                                        16916 non-null  float64
#  35  As, %                                                        16916 non-null  float64
#  36  Mo, %                                                        16916 non-null  float64
#  37  Nb, %                                                        16916 non-null  float64
#  38  Ti, %                                                        16916 non-null  float64
#  39  V, %                                                         16916 non-null  float64
#  40  Al, %                                                        16916 non-null  float64
#  41  Ca, %                                                        16916 non-null  float64
#  42  N, %                                                         16916 non-null  float64
#  43  Pb, %                                                        16916 non-null  float64
#  44  Mg, %                                                        16916 non-null  float64
#  45  Zn, %                                                        16916 non-null  float64
#  46  sleeve                                                       16916 non-null  int64
#  47  num_crystallizer                                             16916 non-null  int64
#  48  num_stream                                                   16916 non-null  int64
#  49  RUL                                                          16916 non-null  float64
#  50  150x150                                                      16916 non-null  float64
#  51  180x180                                                      16916 non-null  float64
#  52  close                                                        16916 non-null  float64
#  53  open                                                         16916 non-null  float64
#  54  B 789/BC                                                     16916 non-null  float64
#  55  SPH-B 795                                                    16916 non-null  float64
# dtypes: float64(40), int64(16)
# memory usage: 7.2 MB

# %%
df.corr()
# Out:
#                                                     workpiece_weight, tonn  \
# workpiece_weight, tonn                                            1.000000
# steel_type                                                        0.126652
# doc_requirement                                                   0.100923
# cast_in_row                                                       0.083493
# steel_weight_theoretical, tonn                                    0.893102
# slag_weight_close_grab1, tonn                                          NaN
# metal_residue_grab1, tonn                                        -0.222096
# steel_weight, tonn                                                0.916641
# grab1_num                                                         0.013182
# steel_temperature_grab1, Celsius deg.                            -0.071727
# grab2_num                                                        -0.003067
# resistance, tonn                                                 -0.008792
# swing_frequency, amount/minute                                   -0.097390
# crystallizer_movement, mm                                         0.005795
# alloy_speed, meter/minute                                         0.078503
# water_consumption, liter/minute                                  -0.057111
# water_temperature_delta, Celsius deg.                             0.034546
# water_consumption_secondary_cooling_zone_num1, ...               -0.008447
# water_consumption_secondary_cooling_zone_num2, ...                0.026068
# water_consumption_secondary_cooling_zone_num3, ...                0.079321
# quantity, tonn                                                   -0.116759
# time_temperature_measurement1                                    -0.007862
# temperature_measurement1, Celsius deg.                           -0.068581
# time_temperature_measurement2                                    -0.007862
# temperature_measurement2, Celsius deg.                           -0.075468
# sample_time_continuous_caster                                    -0.001230
# Ce, %                                                             0.099018
# C, %                                                              0.133115
# Si, %                                                             0.134338
# Mn,%                                                              0.098730
# S, %                                                             -0.052054
# P, %                                                              0.149468
# Cr, %                                                            -0.022337
# Ni, %                                                            -0.023354
# Cu, %                                                            -0.135470
# As, %                                                             0.065943
# Mo, %                                                            -0.068793
# Nb, %                                                            -0.007298
# Ti, %                                                             0.055431
# V, %                                                              0.054441
# Al, %                                                             0.023089
# Ca, %                                                            -0.063920
# N, %                                                             -0.112609
# Pb, %                                                            -0.136785
# Mg, %                                                             0.006011
# Zn, %                                                             0.024354
# sleeve                                                           -0.043421
# num_crystallizer                                                  0.007487
# num_stream                                                       -0.004320
# RUL                                                              -0.005809
# 150x150                                                           0.065886
# 180x180                                                          -0.065886
# close                                                            -0.032835
# open                                                              0.032835
# B 789/BC                                                         -0.063640
# SPH-B 795                                                        -0.001659
#
#                                                     steel_type  \
# workpiece_weight, tonn                                0.126652
# steel_type                                            1.000000
# doc_requirement                                       0.345183
# cast_in_row                                           0.132171
# steel_weight_theoretical, tonn                        0.097850
# slag_weight_close_grab1, tonn                              NaN
# metal_residue_grab1, tonn                             0.001671
# steel_weight, tonn                                    0.095521
# grab1_num                                            -0.049300
# steel_temperature_grab1, Celsius deg.                -0.046147
# grab2_num                                             0.002139
# resistance, tonn                                     -0.038263
# swing_frequency, amount/minute                       -0.199629
# crystallizer_movement, mm                             0.169294
# alloy_speed, meter/minute                             0.406375
# water_consumption, liter/minute                      -0.317157
# water_temperature_delta, Celsius deg.                 0.489416
# water_consumption_secondary_cooling_zone_num1, ...    0.569081
# water_consumption_secondary_cooling_zone_num2, ...    0.624570
# water_consumption_secondary_cooling_zone_num3, ...    0.507296
# quantity, tonn                                       -0.011909
# time_temperature_measurement1                         0.027177
# temperature_measurement1, Celsius deg.               -0.034057
# time_temperature_measurement2                         0.027177
# temperature_measurement2, Celsius deg.               -0.007074
# sample_time_continuous_caster                         0.024441
# Ce, %                                                -0.149925
# C, %                                                  0.166188
# Si, %                                                -0.206439
# Mn,%                                                 -0.010970
# S, %                                                 -0.106024
# P, %                                                  0.092260
# Cr, %                                                 0.066293
# Ni, %                                                -0.015789
# Cu, %                                                -0.049277
# As, %                                                -0.066990
# Mo, %                                                -0.018971
# Nb, %                                                -0.069597
# Ti, %                                                -0.183336
# V, %                                                  0.030771
# Al, %                                                -0.285929
# Ca, %                                                -0.097698
# N, %                                                 -0.144629
# Pb, %                                                -0.140990
# Mg, %                                                -0.069403
# Zn, %                                                -0.015401
# sleeve                                                0.048857
# num_crystallizer                                     -0.015800
# num_stream                                           -0.019988
# RUL                                                  -0.031099
# 150x150                                               0.328634
# 180x180                                              -0.328634
# close                                                -0.401529
# open                                                  0.401529
# B 789/BC                                             -0.086847
# SPH-B 795                                             0.001217
#
#                                                     doc_requirement  \
# workpiece_weight, tonn                                     0.100923
# steel_type                                                 0.345183
# doc_requirement                                            1.000000
# cast_in_row                                                0.041666
# steel_weight_theoretical, tonn                             0.093132
# slag_weight_close_grab1, tonn                                   NaN
# metal_residue_grab1, tonn                                  0.008646
# steel_weight, tonn                                         0.089583
# grab1_num                                                  0.014055
# steel_temperature_grab1, Celsius deg.                     -0.084527
# grab2_num                                                  0.011455
# resistance, tonn                                          -0.036539
# swing_frequency, amount/minute                             0.551276
# crystallizer_movement, mm                                 -0.122293
# alloy_speed, meter/minute                                 -0.546277
# water_consumption, liter/minute                            0.563648
# water_temperature_delta, Celsius deg.                      0.327019
# water_consumption_secondary_cooling_zone_num1, ...        -0.185003
# water_consumption_secondary_cooling_zone_num2, ...        -0.346774
# water_consumption_secondary_cooling_zone_num3, ...        -0.494846
# quantity, tonn                                            -0.028098
# time_temperature_measurement1                              0.073210
# temperature_measurement1, Celsius deg.                    -0.169130
# time_temperature_measurement2                              0.073210
# temperature_measurement2, Celsius deg.                    -0.159930
# sample_time_continuous_caster                              0.077856
# Ce, %                                                      0.289229
# C, %                                                       0.402546
# Si, %                                                      0.185974
# Mn,%                                                       0.255615
# S, %                                                       0.254016
# P, %                                                       0.160458
# Cr, %                                                      0.203956
# Ni, %                                                      0.085674
# Cu, %                                                      0.133127
# As, %                                                     -0.042447
# Mo, %                                                      0.154101
# Nb, %                                                     -0.023658
# Ti, %                                                      0.258812
# V, %                                                       0.160315
# Al, %                                                      0.064138
# Ca, %                                                      0.020884
# N, %                                                       0.238306
# Pb, %                                                      0.327954
# Mg, %                                                      0.306080
# Zn, %                                                      0.332269
# sleeve                                                     0.036909
# num_crystallizer                                           0.002389
# num_stream                                                 0.002661
# RUL                                                       -0.047169
# 150x150                                                   -0.587874
# 180x180                                                    0.587874
# close                                                     -0.197424
# open                                                       0.197424
# B 789/BC                                                   0.118551
# SPH-B 795                                                  0.006294
#
#                                                     cast_in_row  \
# workpiece_weight, tonn                                 0.083493
# steel_type                                             0.132171
# doc_requirement                                        0.041666
# cast_in_row                                            1.000000
# steel_weight_theoretical, tonn                         0.130572
# slag_weight_close_grab1, tonn                               NaN
# metal_residue_grab1, tonn                             -0.008257
# steel_weight, tonn                                     0.129443
# grab1_num                                             -0.029748
# steel_temperature_grab1, Celsius deg.                 -0.101038
# grab2_num                                             -0.002527
# resistance, tonn                                      -0.003085
# swing_frequency, amount/minute                         0.098331
# crystallizer_movement, mm                              0.144622
# alloy_speed, meter/minute                              0.009627
# water_consumption, liter/minute                        0.017491
# water_temperature_delta, Celsius deg.                  0.126782
# water_consumption_secondary_cooling_zone_num1, ...     0.220515
# water_consumption_secondary_cooling_zone_num2, ...     0.132801
# water_consumption_secondary_cooling_zone_num3, ...     0.061103
# quantity, tonn                                        -0.150282
# time_temperature_measurement1                         -0.022814
# temperature_measurement1, Celsius deg.                -0.035247
# time_temperature_measurement2                         -0.022814
# temperature_measurement2, Celsius deg.                -0.015152
# sample_time_continuous_caster                         -0.040762
# Ce, %                                                 -0.217568
# C, %                                                  -0.029174
# Si, %                                                 -0.158468
# Mn,%                                                  -0.217550
# S, %                                                   0.091979
# P, %                                                   0.059512
# Cr, %                                                 -0.057755
# Ni, %                                                  0.006396
# Cu, %                                                  0.009780
# As, %                                                 -0.059177
# Mo, %                                                  0.015849
# Nb, %                                                 -0.118544
# Ti, %                                                 -0.120210
# V, %                                                  -0.129787
# Al, %                                                 -0.027769
# Ca, %                                                 -0.014659
# N, %                                                   0.013448
# Pb, %                                                  0.067379
# Mg, %                                                  0.063630
# Zn, %                                                  0.062642
# sleeve                                                 0.025040
# num_crystallizer                                       0.032271
# num_stream                                             0.009273
# RUL                                                    0.015272
# 150x150                                               -0.025409
# 180x180                                                0.025409
# close                                                 -0.121982
# open                                                   0.121982
# B 789/BC                                               0.078360
# SPH-B 795                                              0.018926
#
#                                                     steel_weight_theoretical, tonn  \
# workpiece_weight, tonn                                                    0.893102
# steel_type                                                                0.097850
# doc_requirement                                                           0.093132
# cast_in_row                                                               0.130572
# steel_weight_theoretical, tonn                                            1.000000
# slag_weight_close_grab1, tonn                                                  NaN
# metal_residue_grab1, tonn                                                -0.013828
# steel_weight, tonn                                                        0.982029
# grab1_num                                                                 0.024571
# steel_temperature_grab1, Celsius deg.                                    -0.074729
# grab2_num                                                                -0.004879
# resistance, tonn                                                         -0.010536
# swing_frequency, amount/minute                                           -0.066322
# crystallizer_movement, mm                                                -0.005871
# alloy_speed, meter/minute                                                 0.064509
# water_consumption, liter/minute                                          -0.046446
# water_temperature_delta, Celsius deg.                                     0.033058
# water_consumption_secondary_cooling_zone_num1, ...                       -0.018346
# water_consumption_secondary_cooling_zone_num2, ...                        0.011488
# water_consumption_secondary_cooling_zone_num3, ...                        0.064697
# quantity, tonn                                                           -0.112739
# time_temperature_measurement1                                            -0.006396
# temperature_measurement1, Celsius deg.                                   -0.074090
# time_temperature_measurement2                                            -0.006396
# temperature_measurement2, Celsius deg.                                   -0.086732
# sample_time_continuous_caster                                             0.003165
# Ce, %                                                                     0.117428
# C, %                                                                      0.131860
# Si, %                                                                     0.151705
# Mn,%                                                                      0.115474
# S, %                                                                     -0.038977
# P, %                                                                      0.160442
# Cr, %                                                                    -0.009787
# Ni, %                                                                    -0.029203
# Cu, %                                                                    -0.120147
# As, %                                                                     0.085027
# Mo, %                                                                    -0.066843
# Nb, %                                                                    -0.005325
# Ti, %                                                                     0.079393
# V, %                                                                      0.070210
# Al, %                                                                     0.046700
# Ca, %                                                                    -0.063205
# N, %                                                                     -0.107056
# Pb, %                                                                    -0.107617
# Mg, %                                                                     0.011076
# Zn, %                                                                     0.028629
# sleeve                                                                   -0.031682
# num_crystallizer                                                          0.011464
# num_stream                                                               -0.004686
# RUL                                                                      -0.007723
# 150x150                                                                   0.056081
# 180x180                                                                  -0.056081
# close                                                                    -0.022688
# open                                                                      0.022688
# B 789/BC                                                                 -0.063139
# SPH-B 795                                                                -0.002664
#
#                                                     slag_weight_close_grab1, tonn  \
# workpiece_weight, tonn                                                        NaN
# steel_type                                                                    NaN
# doc_requirement                                                               NaN
# cast_in_row                                                                   NaN
# steel_weight_theoretical, tonn                                                NaN
# slag_weight_close_grab1, tonn                                                 NaN
# metal_residue_grab1, tonn                                                     NaN
# steel_weight, tonn                                                            NaN
# grab1_num                                                                     NaN
# steel_temperature_grab1, Celsius deg.                                         NaN
# grab2_num                                                                     NaN
# resistance, tonn                                                              NaN
# swing_frequency, amount/minute                                                NaN
# crystallizer_movement, mm                                                     NaN
# alloy_speed, meter/minute                                                     NaN
# water_consumption, liter/minute                                               NaN
# water_temperature_delta, Celsius deg.                                         NaN
# water_consumption_secondary_cooling_zone_num1, ...                            NaN
# water_consumption_secondary_cooling_zone_num2, ...                            NaN
# water_consumption_secondary_cooling_zone_num3, ...                            NaN
# quantity, tonn                                                                NaN
# time_temperature_measurement1                                                 NaN
# temperature_measurement1, Celsius deg.                                        NaN
# time_temperature_measurement2                                                 NaN
# temperature_measurement2, Celsius deg.                                        NaN
# sample_time_continuous_caster                                                 NaN
# Ce, %                                                                         NaN
# C, %                                                                          NaN
# Si, %                                                                         NaN
# Mn,%                                                                          NaN
# S, %                                                                          NaN
# P, %                                                                          NaN
# Cr, %                                                                         NaN
# Ni, %                                                                         NaN
# Cu, %                                                                         NaN
# As, %                                                                         NaN
# Mo, %                                                                         NaN
# Nb, %                                                                         NaN
# Ti, %                                                                         NaN
# V, %                                                                          NaN
# Al, %                                                                         NaN
# Ca, %                                                                         NaN
# N, %                                                                          NaN
# Pb, %                                                                         NaN
# Mg, %                                                                         NaN
# Zn, %                                                                         NaN
# sleeve                                                                        NaN
# num_crystallizer                                                              NaN
# num_stream                                                                    NaN
# RUL                                                                           NaN
# 150x150                                                                       NaN
# 180x180                                                                       NaN
# close                                                                         NaN
# open                                                                          NaN
# B 789/BC                                                                      NaN
# SPH-B 795                                                                     NaN
#
#                                                     metal_residue_grab1, tonn  \
# workpiece_weight, tonn                                          -2.220960e-01
# steel_type                                                       1.671154e-03
# doc_requirement                                                  8.646063e-03
# cast_in_row                                                     -8.257262e-03
# steel_weight_theoretical, tonn                                  -1.382789e-02
# slag_weight_close_grab1, tonn                                             NaN
# metal_residue_grab1, tonn                                        1.000000e+00
# steel_weight, tonn                                              -2.022934e-01
# grab1_num                                                        1.267191e-02
# steel_temperature_grab1, Celsius deg.                           -8.068629e-04
# grab2_num                                                       -6.875984e-04
# resistance, tonn                                                -2.040004e-06
# swing_frequency, amount/minute                                   2.332117e-02
# crystallizer_movement, mm                                       -4.789091e-03
# alloy_speed, meter/minute                                       -8.512602e-03
# water_consumption, liter/minute                                  9.138765e-03
# water_temperature_delta, Celsius deg.                            3.451225e-03
# water_consumption_secondary_cooling_zone_num1, ...               6.132465e-03
# water_consumption_secondary_cooling_zone_num2, ...               2.389682e-03
# water_consumption_secondary_cooling_zone_num3, ...              -3.043339e-03
# quantity, tonn                                                  -4.527444e-03
# time_temperature_measurement1                                    3.681289e-03
# temperature_measurement1, Celsius deg.                          -1.917709e-02
# time_temperature_measurement2                                    3.681289e-03
# temperature_measurement2, Celsius deg.                          -1.642681e-02
# sample_time_continuous_caster                                    4.165849e-03
# Ce, %                                                            2.458918e-16
# C, %                                                             3.803006e-03
# Si, %                                                            2.391409e-03
# Mn,%                                                             3.903011e-02
# S, %                                                             2.275243e-02
# P, %                                                            -6.405301e-03
# Cr, %                                                            2.466374e-02
# Ni, %                                                            5.124532e-03
# Cu, %                                                            3.708960e-02
# As, %                                                           -5.047774e-03
# Mo, %                                                            7.148621e-03
# Nb, %                                                            2.651506e-02
# Ti, %                                                            2.842944e-02
# V, %                                                             3.781119e-02
# Al, %                                                            2.160484e-03
# Ca, %                                                            1.692375e-02
# N, %                                                            -1.254289e-02
# Pb, %                                                            3.474789e-02
# Mg, %                                                           -1.390488e-02
# Zn, %                                                           -1.932238e-02
# sleeve                                                           1.897504e-02
# num_crystallizer                                                -5.809686e-03
# num_stream                                                       5.849431e-03
# RUL                                                             -3.760670e-03
# 150x150                                                         -9.177693e-03
# 180x180                                                          9.177693e-03
# close                                                           -2.421853e-03
# open                                                             2.421853e-03
# B 789/BC                                                         9.168169e-03
# SPH-B 795                                                       -4.061342e-04
#
#                                                     steel_weight, tonn  \
# workpiece_weight, tonn                                        0.916641
# steel_type                                                    0.095521
# doc_requirement                                               0.089583
# cast_in_row                                                   0.129443
# steel_weight_theoretical, tonn                                0.982029
# slag_weight_close_grab1, tonn                                      NaN
# metal_residue_grab1, tonn                                    -0.202293
# steel_weight, tonn                                            1.000000
# grab1_num                                                     0.021674
# steel_temperature_grab1, Celsius deg.                        -0.073039
# grab2_num                                                    -0.004649
# resistance, tonn                                             -0.010319
# swing_frequency, amount/minute                               -0.069359
# crystallizer_movement, mm                                    -0.004846
# alloy_speed, meter/minute                                     0.064789
# water_consumption, liter/minute                              -0.047215
# water_temperature_delta, Celsius deg.                         0.031726
# water_consumption_secondary_cooling_zone_num1, ...           -0.019126
# water_consumption_secondary_cooling_zone_num2, ...            0.010801
# water_consumption_secondary_cooling_zone_num3, ...            0.063940
# quantity, tonn                                               -0.109564
# time_temperature_measurement1                                -0.006959
# temperature_measurement1, Celsius deg.                       -0.068946
# time_temperature_measurement2                                -0.006959
# temperature_measurement2, Celsius deg.                       -0.081847
# sample_time_continuous_caster                                 0.002314
# Ce, %                                                         0.115011
# C, %                                                          0.128428
# Si, %                                                         0.148132
# Mn,%                                                          0.105730
# S, %                                                         -0.042469
# P, %                                                          0.158349
# Cr, %                                                        -0.014241
# Ni, %                                                        -0.029569
# Cu, %                                                        -0.124675
# As, %                                                         0.084230
# Mo, %                                                        -0.066817
# Nb, %                                                        -0.010221
# Ti, %                                                         0.072393
# V, %                                                          0.061628
# Al, %                                                         0.045331
# Ca, %                                                        -0.065098
# N, %                                                         -0.102485
# Pb, %                                                        -0.111961
# Mg, %                                                         0.013473
# Zn, %                                                         0.031687
# sleeve                                                       -0.034611
# num_crystallizer                                              0.012325
# num_stream                                                   -0.005694
# RUL                                                          -0.006854
# 150x150                                                       0.056659
# 180x180                                                      -0.056659
# close                                                        -0.021764
# open                                                          0.021764
# B 789/BC                                                     -0.063570
# SPH-B 795                                                    -0.002532
#
#                                                     grab1_num  \
# workpiece_weight, tonn                               0.013182
# steel_type                                          -0.049300
# doc_requirement                                      0.014055
# cast_in_row                                         -0.029748
# steel_weight_theoretical, tonn                       0.024571
# slag_weight_close_grab1, tonn                             NaN
# metal_residue_grab1, tonn                            0.012672
# steel_weight, tonn                                   0.021674
# grab1_num                                            1.000000
# steel_temperature_grab1, Celsius deg.                0.015159
# grab2_num                                           -0.012576
# resistance, tonn                                    -0.008003
# swing_frequency, amount/minute                       0.026875
# crystallizer_movement, mm                           -0.065895
# alloy_speed, meter/minute                           -0.056483
# water_consumption, liter/minute                      0.048459
# water_temperature_delta, Celsius deg.               -0.019065
# water_consumption_secondary_cooling_zone_num1, ...  -0.034960
# water_consumption_secondary_cooling_zone_num2, ...  -0.065425
# water_consumption_secondary_cooling_zone_num3, ...  -0.050469
# quantity, tonn                                      -0.019938
# time_temperature_measurement1                        0.030797
# temperature_measurement1, Celsius deg.              -0.028375
# time_temperature_measurement2                        0.030797
# temperature_measurement2, Celsius deg.              -0.016029
# sample_time_continuous_caster                        0.028575
# Ce, %                                                0.049859
# C, %                                                 0.034908
# Si, %                                                0.046896
# Mn,%                                                 0.044427
# S, %                                                 0.032957
# P, %                                                 0.020694
# Cr, %                                                0.005340
# Ni, %                                               -0.011318
# Cu, %                                                0.005283
# As, %                                                0.013514
# Mo, %                                               -0.024320
# Nb, %                                                0.047340
# Ti, %                                                0.054859
# V, %                                                 0.028254
# Al, %                                               -0.023940
# Ca, %                                                0.036331
# N, %                                                -0.002670
# Pb, %                                                0.008644
# Mg, %                                               -0.010194
# Zn, %                                               -0.033563
# sleeve                                              -0.048627
# num_crystallizer                                     0.004105
# num_stream                                          -0.000573
# RUL                                                 -0.003213
# 150x150                                             -0.054257
# 180x180                                              0.054257
# close                                               -0.010319
# open                                                 0.010319
# B 789/BC                                             0.014368
# SPH-B 795                                            0.003138
#
#                                                     steel_temperature_grab1, Celsius deg.  \
# workpiece_weight, tonn                                                          -0.071727
# steel_type                                                                      -0.046147
# doc_requirement                                                                 -0.084527
# cast_in_row                                                                     -0.101038
# steel_weight_theoretical, tonn                                                  -0.074729
# slag_weight_close_grab1, tonn                                                         NaN
# metal_residue_grab1, tonn                                                       -0.000807
# steel_weight, tonn                                                              -0.073039
# grab1_num                                                                        0.015159
# steel_temperature_grab1, Celsius deg.                                            1.000000
# grab2_num                                                                       -0.005192
# resistance, tonn                                                                 0.002626
# swing_frequency, amount/minute                                                  -0.072934
# crystallizer_movement, mm                                                       -0.041251
# alloy_speed, meter/minute                                                        0.024447
# water_consumption, liter/minute                                                 -0.039624
# water_temperature_delta, Celsius deg.                                           -0.085148
# water_consumption_secondary_cooling_zone_num1, ...                              -0.028921
# water_consumption_secondary_cooling_zone_num2, ...                              -0.009339
# water_consumption_secondary_cooling_zone_num3, ...                               0.016175
# quantity, tonn                                                                   0.053169
# time_temperature_measurement1                                                   -0.035608
# temperature_measurement1, Celsius deg.                                           0.118754
# time_temperature_measurement2                                                   -0.035608
# temperature_measurement2, Celsius deg.                                           0.116002
# sample_time_continuous_caster                                                   -0.040391
# Ce, %                                                                           -0.083957
# C, %                                                                            -0.128583
# Si, %                                                                           -0.069620
# Mn,%                                                                            -0.095547
# S, %                                                                            -0.015389
# P, %                                                                            -0.062148
# Cr, %                                                                           -0.037842
# Ni, %                                                                            0.007431
# Cu, %                                                                            0.005987
# As, %                                                                            0.020560
# Mo, %                                                                           -0.021623
# Nb, %                                                                           -0.004398
# Ti, %                                                                           -0.080753
# V, %                                                                            -0.053084
# Al, %                                                                           -0.022338
# Ca, %                                                                            0.011163
# N, %                                                                            -0.031773
# Pb, %                                                                           -0.070672
# Mg, %                                                                           -0.066885
# Zn, %                                                                           -0.045688
# sleeve                                                                          -0.032011
# num_crystallizer                                                                -0.008646
# num_stream                                                                       0.008349
# RUL                                                                              0.002544
# 150x150                                                                          0.042536
# 180x180                                                                         -0.042536
# close                                                                            0.064416
# open                                                                            -0.064416
# B 789/BC                                                                        -0.014936
# SPH-B 795                                                                        0.000844
#
#                                                     grab2_num  \
# workpiece_weight, tonn                              -0.003067
# steel_type                                           0.002139
# doc_requirement                                      0.011455
# cast_in_row                                         -0.002527
# steel_weight_theoretical, tonn                      -0.004879
# slag_weight_close_grab1, tonn                             NaN
# metal_residue_grab1, tonn                           -0.000688
# steel_weight, tonn                                  -0.004649
# grab1_num                                           -0.012576
# steel_temperature_grab1, Celsius deg.               -0.005192
# grab2_num                                            1.000000
# resistance, tonn                                     0.000669
# swing_frequency, amount/minute                       0.017663
# crystallizer_movement, mm                           -0.024262
# alloy_speed, meter/minute                           -0.011338
# water_consumption, liter/minute                      0.012162
# water_temperature_delta, Celsius deg.                0.004601
# water_consumption_secondary_cooling_zone_num1, ...  -0.003025
# water_consumption_secondary_cooling_zone_num2, ...  -0.003623
# water_consumption_secondary_cooling_zone_num3, ...  -0.010275
# quantity, tonn                                      -0.006057
# time_temperature_measurement1                        0.041505
# temperature_measurement1, Celsius deg.              -0.012559
# time_temperature_measurement2                        0.041505
# temperature_measurement2, Celsius deg.              -0.003574
# sample_time_continuous_caster                        0.042603
# Ce, %                                               -0.003206
# C, %                                                 0.003267
# Si, %                                               -0.004503
# Mn,%                                                -0.005523
# S, %                                                 0.009504
# P, %                                                 0.011331
# Cr, %                                                0.001285
# Ni, %                                                0.006942
# Cu, %                                                0.021495
# As, %                                                0.033898
# Mo, %                                                0.015846
# Nb, %                                                0.019641
# Ti, %                                                0.019872
# V, %                                                 0.001259
# Al, %                                                0.021440
# Ca, %                                                0.009146
# N, %                                                -0.000856
# Pb, %                                                0.031319
# Mg, %                                                0.012107
# Zn, %                                                0.009823
# sleeve                                              -0.018091
# num_crystallizer                                     0.002852
# num_stream                                          -0.001545
# RUL                                                 -0.004659
# 150x150                                             -0.012227
# 180x180                                              0.012227
# close                                               -0.003238
# open                                                 0.003238
# B 789/BC                                             0.012296
# SPH-B 795                                           -0.000577
#
#                                                     resistance, tonn  \
# workpiece_weight, tonn                                     -0.008792
# steel_type                                                 -0.038263
# doc_requirement                                            -0.036539
# cast_in_row                                                -0.003085
# steel_weight_theoretical, tonn                             -0.010536
# slag_weight_close_grab1, tonn                                    NaN
# metal_residue_grab1, tonn                                  -0.000002
# ...
# swing_frequency, amount/minute                        0.016838 -0.019123
# crystallizer_movement, mm                             0.004472  0.000694
# alloy_speed, meter/minute                            -0.026209  0.020466
# water_consumption, liter/minute                       0.024273 -0.015180
# water_temperature_delta, Celsius deg.                -0.017673  0.001665
# water_consumption_secondary_cooling_zone_num1, ...   -0.001600  0.031780
# water_consumption_secondary_cooling_zone_num2, ...   -0.021436  0.012220
# water_consumption_secondary_cooling_zone_num3, ...   -0.028274  0.027177
# quantity, tonn                                       -0.000745  0.003729
# time_temperature_measurement1                        -0.004748 -0.001665
# temperature_measurement1, Celsius deg.                0.010767  0.004789
# time_temperature_measurement2                        -0.004748 -0.001665
# temperature_measurement2, Celsius deg.                0.013573  0.000250
# sample_time_continuous_caster                        -0.006973 -0.002009
# Ce, %                                                -0.017698 -0.032094
# C, %                                                 -0.016068 -0.022856
# Si, %                                                -0.009890 -0.026428
# Mn,%                                                 -0.008480 -0.012232
# S, %                                                  0.011723 -0.002081
# P, %                                                  0.012041  0.016870
# Cr, %                                                 0.020850 -0.022700
# Ni, %                                                 0.006058  0.030487
# Cu, %                                                 0.015176 -0.017899
# As, %                                                -0.017729 -0.001632
# Mo, %                                                 0.016060 -0.036798
# Nb, %                                                 0.014380 -0.025644
# Ti, %                                                 0.004263 -0.043512
# V, %                                                  0.003494 -0.039222
# Al, %                                                 0.026279 -0.017400
# Ca, %                                                 0.008001 -0.005711
# N, %                                                  0.028004 -0.078368
# Pb, %                                                 0.024847 -0.057123
# Mg, %                                                -0.001068 -0.044544
# Zn, %                                                -0.014687 -0.030620
# sleeve                                                0.064912 -0.085730
# num_crystallizer                                      0.030488  0.066243
# num_stream                                            1.000000  0.087602
# RUL                                                   0.087602  1.000000
# 150x150                                              -0.024631  0.015335
# 180x180                                               0.024631 -0.015335
# close                                                 0.016695 -0.016145
# open                                                 -0.016695  0.016145
# B 789/BC                                              0.003713 -0.032799
# SPH-B 795                                             0.000479 -0.002655
#
#                                                      150x150   180x180  \
# workpiece_weight, tonn                              0.065886 -0.065886
# steel_type                                          0.328634 -0.328634
# doc_requirement                                    -0.587874  0.587874
# cast_in_row                                        -0.025409  0.025409
# steel_weight_theoretical, tonn                      0.056081 -0.056081
# slag_weight_close_grab1, tonn                            NaN       NaN
# metal_residue_grab1, tonn                          -0.009178  0.009178
# steel_weight, tonn                                  0.056659 -0.056659
# grab1_num                                          -0.054257  0.054257
# steel_temperature_grab1, Celsius deg.               0.042536 -0.042536
# grab2_num                                          -0.012227  0.012227
# resistance, tonn                                   -0.006199  0.006199
# swing_frequency, amount/minute                     -0.785484  0.785484
# crystallizer_movement, mm                           0.257788 -0.257788
# alloy_speed, meter/minute                           0.953698 -0.953698
# water_consumption, liter/minute                    -0.960473  0.960473
# water_temperature_delta, Celsius deg.              -0.180674  0.180674
# water_consumption_secondary_cooling_zone_num1, ...  0.328244 -0.328244
# water_consumption_secondary_cooling_zone_num2, ...  0.634098 -0.634098
# water_consumption_secondary_cooling_zone_num3, ...  0.880652 -0.880652
# quantity, tonn                                      0.033031 -0.033031
# time_temperature_measurement1                      -0.022586  0.022586
# temperature_measurement1, Celsius deg.              0.119921 -0.119921
# time_temperature_measurement2                      -0.022586  0.022586
# temperature_measurement2, Celsius deg.              0.120518 -0.120518
# sample_time_continuous_caster                      -0.023007  0.023007
# Ce, %                                              -0.125444  0.125444
# C, %                                               -0.116323  0.116323
# Si, %                                               0.006176 -0.006176
# Mn,%                                               -0.124825  0.124825
# S, %                                               -0.368248  0.368248
# P, %                                               -0.135417  0.135417
# Cr, %                                              -0.167871  0.167871
# Ni, %                                              -0.099773  0.099773
# Cu, %                                              -0.215716  0.215716
# As, %                                               0.088515 -0.088515
# Mo, %                                              -0.160904  0.160904
# Nb, %                                               0.021229 -0.021229
# Ti, %                                              -0.220194  0.220194
# V, %                                               -0.047805  0.047805
# Al, %                                              -0.199737  0.199737
# Ca, %                                              -0.136653  0.136653
# N, %                                               -0.338187  0.338187
# Pb, %                                              -0.509443  0.509443
# Mg, %                                              -0.355879  0.355879
# Zn, %                                              -0.317875  0.317875
# sleeve                                              0.005575 -0.005575
# num_crystallizer                                   -0.014459  0.014459
# num_stream                                         -0.024631  0.024631
# RUL                                                 0.015335 -0.015335
# 150x150                                             1.000000 -1.000000
# 180x180                                            -1.000000  1.000000
# close                                               0.203485 -0.203485
# open                                               -0.203485  0.203485
# B 789/BC                                           -0.256142  0.256142
# SPH-B 795                                          -0.006681  0.006681
#
#                                                        close      open  \
# workpiece_weight, tonn                             -0.032835  0.032835
# steel_type                                         -0.401529  0.401529
# doc_requirement                                    -0.197424  0.197424
# cast_in_row                                        -0.121982  0.121982
# steel_weight_theoretical, tonn                     -0.022688  0.022688
# slag_weight_close_grab1, tonn                            NaN       NaN
# metal_residue_grab1, tonn                          -0.002422  0.002422
# steel_weight, tonn                                 -0.021764  0.021764
# grab1_num                                          -0.010319  0.010319
# steel_temperature_grab1, Celsius deg.               0.064416 -0.064416
# grab2_num                                          -0.003238  0.003238
# resistance, tonn                                   -0.001581  0.001581
# swing_frequency, amount/minute                     -0.133060  0.133060
# crystallizer_movement, mm                          -0.076882  0.076882
# alloy_speed, meter/minute                           0.011796 -0.011796
# water_consumption, liter/minute                    -0.195162  0.195162
# water_temperature_delta, Celsius deg.              -0.775027  0.775027
# water_consumption_secondary_cooling_zone_num1, ... -0.492151  0.492151
# water_consumption_secondary_cooling_zone_num2, ... -0.346677  0.346677
# water_consumption_secondary_cooling_zone_num3, ... -0.095982  0.095982
# quantity, tonn                                      0.039467 -0.039467
# time_temperature_measurement1                       0.038401 -0.038401
# temperature_measurement1, Celsius deg.              0.155820 -0.155820
# time_temperature_measurement2                       0.038401 -0.038401
# temperature_measurement2, Celsius deg.              0.126392 -0.126392
# sample_time_continuous_caster                       0.041454 -0.041454
# Ce, %                                              -0.001519  0.001519
# C, %                                               -0.379155  0.379155
# Si, %                                              -0.002496  0.002496
# Mn,%                                               -0.108294  0.108294
# S, %                                               -0.092301  0.092301
# P, %                                               -0.090464  0.090464
# Cr, %                                              -0.116362  0.116362
# Ni, %                                              -0.037682  0.037682
# Cu, %                                              -0.101555  0.101555
# As, %                                              -0.000519  0.000519
# Mo, %                                              -0.018814  0.018814
# Nb, %                                               0.054219 -0.054219
# Ti, %                                              -0.064015  0.064015
# V, %                                               -0.051473  0.051473
# Al, %                                               0.120401 -0.120401
# Ca, %                                              -0.057892  0.057892
# N, %                                               -0.064999  0.064999
# Pb, %                                              -0.134434  0.134434
# Mg, %                                              -0.093911  0.093911
# Zn, %                                              -0.083882  0.083882
# sleeve                                              0.012227 -0.012227
# num_crystallizer                                   -0.023428  0.023428
# num_stream                                          0.016695 -0.016695
# RUL                                                -0.016145  0.016145
# 150x150                                             0.203485 -0.203485
# 180x180                                            -0.203485  0.203485
# close                                               1.000000 -1.000000
# open                                               -1.000000  1.000000
# B 789/BC                                           -0.043097  0.043097
# SPH-B 795                                          -0.001763  0.001763
#
#                                                     B 789/BC  SPH-B 795
# workpiece_weight, tonn                             -0.063640  -0.001659
# steel_type                                         -0.086847   0.001217
# doc_requirement                                     0.118551   0.006294
# cast_in_row                                         0.078360   0.018926
# steel_weight_theoretical, tonn                     -0.063139  -0.002664
# slag_weight_close_grab1, tonn                            NaN        NaN
# metal_residue_grab1, tonn                           0.009168  -0.000406
# steel_weight, tonn                                 -0.063570  -0.002532
# grab1_num                                           0.014368   0.003138
# steel_temperature_grab1, Celsius deg.              -0.014936   0.000844
# grab2_num                                           0.012296  -0.000577
# resistance, tonn                                    0.009247  -0.000906
# swing_frequency, amount/minute                      0.281932   0.009678
# crystallizer_movement, mm                           0.092129   0.025154
# alloy_speed, meter/minute                          -0.240849  -0.006197
# water_consumption, liter/minute                     0.243972   0.005454
# water_temperature_delta, Celsius deg.              -0.013402   0.002512
# water_consumption_secondary_cooling_zone_num1, ... -0.012557   0.004464
# water_consumption_secondary_cooling_zone_num2, ... -0.054174   0.002945
# water_consumption_secondary_cooling_zone_num3, ... -0.222682   0.001143
# quantity, tonn                                      0.000168  -0.003296
# time_temperature_measurement1                       0.028764  -0.021665
# temperature_measurement1, Celsius deg.             -0.016966   0.006718
# time_temperature_measurement2                       0.028764  -0.021665
# temperature_measurement2, Celsius deg.             -0.001608   0.003434
# sample_time_continuous_caster                       0.028401  -0.021328
# Ce, %                                              -0.078083  -0.001836
# C, %                                               -0.045952   0.007591
# Si, %                                              -0.074061   0.003396
# Mn,%                                               -0.056980  -0.003059
# S, %                                                0.142060  -0.010085
# P, %                                                0.081321  -0.000020
# Cr, %                                               0.046702   0.004691
# Ni, %                                              -0.057198   0.007661
# Cu, %                                               0.069199   0.005504
# As, %                                              -0.174474   0.012605
# Mo, %                                               0.005436   0.004943
# Nb, %                                              -0.036407   0.006247
# Ti, %                                               0.063165  -0.003821
# V, %                                               -0.009677  -0.003744
# Al, %                                               0.052507   0.011713
# Ca, %                                               0.072486  -0.006532
# N, %                                                0.132458   0.003804
# Pb, %                                               0.266624   0.002906
# Mg, %                                               0.111818   0.006619
# Zn, %                                               0.115353   0.026674
# sleeve                                              0.035920   0.015324
# num_crystallizer                                    0.004501   0.000160
# num_stream                                          0.003713   0.000479
# RUL                                                -0.032799  -0.002655
# 150x150                                            -0.256142  -0.006681
# 180x180                                             0.256142   0.006681
# close                                              -0.043097  -0.001763
# open                                                0.043097   0.001763
# B 789/BC                                            1.000000  -0.044298
# SPH-B 795                                          -0.044298   1.000000

# %%
df = df.drop('slag_weight_close_grab1, tonn',axis=1)

# %%
df.columns
# Out:
# Index(['workpiece_weight, tonn', 'steel_type', 'doc_requirement',
#        'cast_in_row', 'steel_weight_theoretical, tonn',
#        'metal_residue_grab1, tonn', 'steel_weight, tonn', 'grab1_num',
#        'steel_temperature_grab1, Celsius deg.', 'grab2_num',
#        'resistance, tonn', 'swing_frequency, amount/minute',
#        'crystallizer_movement, mm', 'alloy_speed, meter/minute',
#        'water_consumption, liter/minute',
#        'water_temperature_delta, Celsius deg.',
#        'water_consumption_secondary_cooling_zone_num1, liter/minute',
#        'water_consumption_secondary_cooling_zone_num2, liter/minute',
#        'water_consumption_secondary_cooling_zone_num3, liter/minute',
#        'quantity, tonn', 'time_temperature_measurement1',
#        'temperature_measurement1, Celsius deg.',
#        'time_temperature_measurement2',
#        'temperature_measurement2, Celsius deg.',
#        'sample_time_continuous_caster', 'Ce, %', 'C, %', 'Si, %', 'Mn,%',
#        'S, %', 'P, %', 'Cr, %', 'Ni, %', 'Cu, %', 'As, %', 'Mo, %', 'Nb, %',
#        'Ti, %', 'V, %', 'Al, %', 'Ca, %', 'N, %', 'Pb, %', 'Mg, %', 'Zn, %',
#        'sleeve', 'num_crystallizer', 'num_stream', 'RUL', '150x150', '180x180',
#        'close', 'open', 'B 789/BC', 'SPH-B 795'],
#       dtype='object')

# %%
X = df[['workpiece_weight, tonn', 'steel_type', 'doc_requirement',
       'cast_in_row', 'steel_weight_theoretical, tonn',
       'metal_residue_grab1, tonn', 'steel_weight, tonn', 'grab1_num',
       'steel_temperature_grab1, Celsius deg.', 'grab2_num',
       'resistance, tonn', 'swing_frequency, amount/minute',
       'crystallizer_movement, mm', 'alloy_speed, meter/minute',
       'water_consumption, liter/minute',
       'water_temperature_delta, Celsius deg.',
       'water_consumption_secondary_cooling_zone_num1, liter/minute',
       'water_consumption_secondary_cooling_zone_num2, liter/minute',
       'water_consumption_secondary_cooling_zone_num3, liter/minute',
       'quantity, tonn', 'time_temperature_measurement1',
       'temperature_measurement1, Celsius deg.',
       'time_temperature_measurement2',
       'temperature_measurement2, Celsius deg.',
       'sample_time_continuous_caster', 'Ce, %', 'C, %', 'Si, %', 'Mn,%',
       'S, %', 'P, %', 'Cr, %', 'Ni, %', 'Cu, %', 'As, %', 'Mo, %', 'Nb, %',
       'Ti, %', 'V, %', 'Al, %', 'Ca, %', 'N, %', 'Pb, %', 'Mg, %', 'Zn, %',
       'sleeve', 'num_crystallizer', 'num_stream', '150x150', '180x180',
       'close', 'open', 'B 789/BC', 'SPH-B 795']]
y = df[['RUL']]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33)

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
linear = LinearRegression()
linear.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#For feature importance in linear regression model

#Getting the importance of all the features
feature_importance = linear.coef_

# If feature_importance is 2D, flatten it to 1D
if len(feature_importance.shape) > 1:
    feature_importance = feature_importance.ravel()
    
# Create a DataFrame to store feature names and their importance
feature_names = X.columns.to_list()
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})

# Scale the importance values between 0 and 1 using Min-Max scaling
scaler = MinMaxScaler()
importance_df['Scaled Importance'] = scaler.fit_transform(importance_df[['Importance']])

# Create a bar plot
plt.figure(figsize=(25, 25))
plt.barh(importance_df['Feature'], importance_df['Scaled Importance'])
plt.xlabel('Scaled Importance (0 to 1)')
plt.xlabel('Features')
plt.title('Feature Importance (Scaled) in Linear Regression')
plt.show()

#For writing labels in slanting
# plt.xticks(rotation=45)
print(pd.merge(importance_df['Feature'],importance_df['Scaled Importance'],left_index=True,right_index=True))
# Out:
#                                               Feature  Scaled Importance
# 0                              workpiece_weight, tonn           0.842761
# 1                                          steel_type           0.842357
# 2                                     doc_requirement           0.842964
# 3                                         cast_in_row           0.842769
# 4                      steel_weight_theoretical, tonn           0.842754
# 5                           metal_residue_grab1, tonn           0.842750
# 6                                  steel_weight, tonn           0.842772
# 7                                           grab1_num           0.842752
# 8               steel_temperature_grab1, Celsius deg.           0.842767
# 9                                           grab2_num           0.842767
# 10                                   resistance, tonn           0.842767
# 11                     swing_frequency, amount/minute           0.842790
# 12                          crystallizer_movement, mm           0.842762
# 13                          alloy_speed, meter/minute           0.843119
# 14                    water_consumption, liter/minute           0.842767
# 15              water_temperature_delta, Celsius deg.           0.842895
# 16  water_consumption_secondary_cooling_zone_num1,...           0.842774
# 17  water_consumption_secondary_cooling_zone_num2,...           0.842759
# 18  water_consumption_secondary_cooling_zone_num3,...           0.842779
# 19                                     quantity, tonn           0.843104
# 20                      time_temperature_measurement1           0.842768
# 21             temperature_measurement1, Celsius deg.           0.842770
# 22                      time_temperature_measurement2           0.842768
# 23             temperature_measurement2, Celsius deg.           0.842759
# 24                      sample_time_continuous_caster           0.842767
# 25                                              Ce, %           0.838606
# 26                                               C, %           0.844019
# 27                                              Si, %           0.839546
# 28                                               Mn,%           0.844143
# 29                                               S, %           0.867075
# 30                                               P, %           0.861882
# 31                                              Cr, %           0.842975
# 32                                              Ni, %           0.877814
# 33                                              Cu, %           0.836921
# 34                                              As, %           0.661188
# 35                                              Mo, %           0.734932
# 36                                              Nb, %           0.000000
# 37                                              Ti, %           0.776785
# 38                                               V, %           0.779124
# 39                                              Al, %           0.934334
# 40                                              Ca, %           1.000000
# 41                                               N, %           0.732977
# 42                                              Pb, %           0.768423
# 43                                              Mg, %           0.428316
# 44                                              Zn, %           0.833913
# 45                                             sleeve           0.842756
# 46                                   num_crystallizer           0.842801
# 47                                         num_stream           0.842959
# 48                                            150x150           0.843242
# 49                                            180x180           0.842293
# 50                                              close           0.841809
# 51                                               open           0.843726
# 52                                           B 789/BC           0.842547
# 53                                          SPH-B 795           0.842527

# %%
shap_explainer = shap.Explainer(linear,X_train)
shap_values = shap_explainer(X_test)
shap.summary_plot(shap_values)

# %%
linear.score(X_test,y_test)
# Out:
# 0.039159051853501436

# %% [markdown]
# #### Cross Validation Score, to check for overfitting, and get a generalized accuracy

# %%
score_lr=cross_val_score(LinearRegression(),X_test,y_test,cv=3)
print(score_lr)
print("Avg :",np.average(score_lr))
# Out:
# [0.01782997 0.03272147 0.03250392]
# Avg : 0.027685119442302415

# %%
decision = DecisionTreeRegressor()
decision.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
decision.score(X_test,y_test)
# Out:
# 0.9698340863551203

# %%
#Cross Validation Score, to check for overfitting, and get a generalized accuracy
score_dt=cross_val_score(DecisionTreeRegressor(),X_test,y_test,cv=3)
print(score_dt)
print("Avg :",np.average(score_dt))
# Out:
# [0.87203762 0.91449139 0.91446305]
# Avg : 0.9003306872051677

# %%
# for i in tqdm(range(0, 100)):
#     shap_explainer = shap.TreeExplainer(decision)
#     shap_values = shap_explainer.shap_values(X)
#     shap.summary_plot(shap_values)

# %%
sort = decision.feature_importances_.argsort()
plt.barh(X.columns[sort], decision.feature_importances_[sort])
plt.xlabel("Feature Importance")
print(pd.DataFrame(decision.feature_importances_[sort],X.columns[sort]))
# Out:
#                                                                0
# SPH-B 795                                           0.000000e+00
# metal_residue_grab1, tonn                           0.000000e+00
# close                                               4.080797e-14
# open                                                4.202169e-14
# steel_weight, tonn                                  2.185295e-11
# workpiece_weight, tonn                              2.649579e-11
# grab1_num                                           4.949239e-11
# water_temperature_delta, Celsius deg.               5.302064e-11
# steel_weight_theoretical, tonn                      8.037227e-11
# quantity, tonn                                      1.540624e-10
# water_consumption, liter/minute                     1.635514e-10
# B 789/BC                                            2.397171e-10
# Mg, %                                               2.937050e-10
# steel_temperature_grab1, Celsius deg.               4.629916e-10
# water_consumption_secondary_cooling_zone_num1, ...  4.940958e-10
# time_temperature_measurement1                       4.975849e-10
# Mo, %                                               5.486309e-10
# Ca, %                                               7.192705e-10
# sample_time_continuous_caster                       7.577582e-10
# time_temperature_measurement2                       9.407198e-10
# P, %                                                1.040830e-09
# Cr, %                                               1.408516e-09
# Cu, %                                               1.794406e-09
# swing_frequency, amount/minute                      2.032193e-09
# Si, %                                               2.121745e-09
# crystallizer_movement, mm                           2.295250e-09
# water_consumption_secondary_cooling_zone_num3, ...  2.571279e-09
# As, %                                               3.176633e-09
# temperature_measurement2, Celsius deg.              3.639597e-09
# 180x180                                             3.735187e-09
# S, %                                                3.906532e-09
# alloy_speed, meter/minute                           5.192156e-09
# Ti, %                                               6.023485e-09
# 150x150                                             6.179827e-09
# Al, %                                               1.141453e-08
# Mn,%                                                1.174218e-08
# doc_requirement                                     1.302313e-08
# steel_type                                          2.309751e-08
# Pb, %                                               6.912407e-08
# Zn, %                                               4.112561e-06
# C, %                                                1.284751e-03
# water_consumption_secondary_cooling_zone_num2, ...  1.492185e-03
# temperature_measurement1, Celsius deg.              2.578172e-03
# Ce, %                                               5.922727e-03
# cast_in_row                                         6.181080e-03
# grab2_num                                           7.487398e-03
# Nb, %                                               8.063366e-03
# resistance, tonn                                    1.728196e-02
# Ni, %                                               3.593212e-02
# N, %                                                8.095920e-02
# num_stream                                          1.093264e-01
# V, %                                                1.713258e-01
# num_crystallizer                                    2.308121e-01
# sleeve                                              3.213485e-01

# %%
random = RandomForestRegressor()
random.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
random.score(X_test,y_test)
# Out:
# 0.9947372495621623

# %%
#Cross Validation Score, to check for overfitting, and get a generalized accuracy
score_rf=cross_val_score(RandomForestRegressor(),X_test,y_test,cv=3)
print(score_rf)
print("Avg :",np.average(score_rf))
# Out:
# [0.98049008 0.97677569 0.96828255]
# Avg : 0.9751827734970991

# %%
# for i in tqdm(range(0, 100)):
#     shap_explainer = shap.TreeExplainer(random)
#     shap_values = shap_explainer.shap_values(X)
#     shap.summary_plot(shap_values, X)

# %%
#Feature importance in order to analyse the input features
sort = random.feature_importances_.argsort()
plt.barh(X.columns[sort], random.feature_importances_[sort])
plt.xlabel("Feature Importance")
plt.figure(figsize=(20,20))
print(pd.DataFrame(random.feature_importances_[sort],X.columns[sort]))
# Out:
#                                                                0
# SPH-B 795                                           1.141089e-15
# metal_residue_grab1, tonn                           2.724550e-13
# close                                               8.096398e-11
# open                                                2.143717e-10
# grab1_num                                           6.533512e-10
# water_temperature_delta, Celsius deg.               9.620191e-10
# alloy_speed, meter/minute                           1.863985e-09
# doc_requirement                                     1.882559e-09
# B 789/BC                                            2.637122e-05
# quantity, tonn                                      3.514197e-05
# water_consumption, liter/minute                     6.904078e-05
# time_temperature_measurement2                       1.456694e-04
# 150x150                                             1.702193e-04
# Mg, %                                               2.014742e-04
# 180x180                                             2.516682e-04
# As, %                                               2.832394e-04
# workpiece_weight, tonn                              3.129086e-04
# steel_type                                          3.313865e-04
# time_temperature_measurement1                       3.327168e-04
# Ti, %                                               3.429869e-04
# Ca, %                                               3.649250e-04
# steel_weight, tonn                                  4.010768e-04
# crystallizer_movement, mm                           4.117864e-04
# sample_time_continuous_caster                       4.127675e-04
# steel_weight_theoretical, tonn                      4.148424e-04
# Cu, %                                               4.912961e-04
# S, %                                                4.989428e-04
# Zn, %                                               5.703439e-04
# temperature_measurement1, Celsius deg.              6.123604e-04
# water_consumption_secondary_cooling_zone_num3, ...  6.129440e-04
# temperature_measurement2, Celsius deg.              6.311675e-04
# cast_in_row                                         7.057778e-04
# Si, %                                               7.360119e-04
# swing_frequency, amount/minute                      7.780995e-04
# Pb, %                                               8.009267e-04
# P, %                                                8.208175e-04
# steel_temperature_grab1, Celsius deg.               1.021340e-03
# water_consumption_secondary_cooling_zone_num1, ...  1.228262e-03
# Cr, %                                               1.338737e-03
# Al, %                                               1.732395e-03
# C, %                                                1.758614e-03
# grab2_num                                           1.764741e-03
# Mn,%                                                2.781608e-03
# Mo, %                                               3.634198e-03
# water_consumption_secondary_cooling_zone_num2, ...  5.890669e-03
# Nb, %                                               8.606483e-03
# Ce, %                                               1.089697e-02
# resistance, tonn                                    1.773920e-02
# Ni, %                                               2.413936e-02
# N, %                                                4.761339e-02
# num_stream                                          1.001112e-01
# V, %                                                1.886606e-01
# num_crystallizer                                    2.362174e-01
# sleeve                                              3.330979e-01

# %%
xgb = XGBRegressor()
xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
xgb.score(X_test,y_test)
# Out:
# 0.9941483785350159

# %%
#Cross Validation Score, to check for overfitting, and get a generalized accuracy
score_xgb=cross_val_score(XGBRegressor(),X_test,y_test,cv=3)
print(score_xgb)
print("Avg :",np.average(score_xgb))
# Out:
# [0.96805115 0.87642136 0.95407815]
# Avg : 0.9328502225358286

# %%
sort = xgb.feature_importances_.argsort()
plt.barh(X.columns[sort], xgb.feature_importances_[sort])
plt.xlabel("Feature Importance")
print(pd.DataFrame(xgb.feature_importances_[sort],X.columns[sort]))
# Out:
#                                                            0
# SPH-B 795                                           0.000000
# 150x150                                             0.000000
# 180x180                                             0.000000
# close                                               0.000000
# water_temperature_delta, Celsius deg.               0.000000
# steel_weight, tonn                                  0.000000
# time_temperature_measurement2                       0.000000
# open                                                0.000000
# metal_residue_grab1, tonn                           0.000000
# B 789/BC                                            0.000006
# Zn, %                                               0.000007
# water_consumption, liter/minute                     0.000010
# crystallizer_movement, mm                           0.000010
# water_consumption_secondary_cooling_zone_num3, ...  0.000011
# Mg, %                                               0.000012
# doc_requirement                                     0.000012
# As, %                                               0.000014
# water_consumption_secondary_cooling_zone_num1, ...  0.000014
# temperature_measurement2, Celsius deg.              0.000020
# Ca, %                                               0.000047
# swing_frequency, amount/minute                      0.000055
# alloy_speed, meter/minute                           0.000058
# time_temperature_measurement1                       0.000094
# steel_weight_theoretical, tonn                      0.000181
# S, %                                                0.000223
# Cu, %                                               0.000243
# steel_temperature_grab1, Celsius deg.               0.000411
# temperature_measurement1, Celsius deg.              0.000474
# grab1_num                                           0.000726
# P, %                                                0.000970
# Ti, %                                               0.000979
# steel_type                                          0.000987
# Al, %                                               0.001006
# quantity, tonn                                      0.001103
# workpiece_weight, tonn                              0.001142
# sample_time_continuous_caster                       0.001282
# Cr, %                                               0.001805
# cast_in_row                                         0.002621
# Si, %                                               0.003038
# Pb, %                                               0.003667
# Mo, %                                               0.005888
# resistance, tonn                                    0.005988
# C, %                                                0.006736
# water_consumption_secondary_cooling_zone_num2, ...  0.010245
# grab2_num                                           0.015117
# Ce, %                                               0.022273
# Mn,%                                                0.030128
# Nb, %                                               0.031291
# Ni, %                                               0.054190
# num_stream                                          0.057998
# N, %                                                0.071595
# sleeve                                              0.116722
# num_crystallizer                                    0.128256
# V, %                                                0.422345

# %%
# for i in tqdm(range(0, 100)):
#     shap_explainer = shap.TreeExplainer(gradientBoost)
#     shap_values = shap_explainer.shap_values(X)
#     shap.summary_plot(shap_values, X)

# %%
# corr_matrix = df.corr()
# columns = corr_matrix[corr_matrix>0.0001]
# columns['RUL']
